# %% [markdown]
# # SW 05 - QQ-Plots und Parameterschätzung
# ## Normal-Plot

# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt

# %%
x = np.array([24.4, 27.6, 27.8, 27.9, 28.5, 30.1, 30.1, 30.3, 31.7, 32.2, 32.8, 33.3, 33.5, 34.1, 34.6, 35.8, 35.9, 36.8, 37.1, 39.2, 39.7])
st.probplot(x, plot=plt)
# Out:
# ((array([-1.84569542, -1.41352783, -1.14765351, -0.94487504, -0.77501005,
#          -0.62504005, -0.48799157, -0.35957249, -0.23684388, -0.11759451,
#           0.        ,  0.11759451,  0.23684388,  0.35957249,  0.48799157,
#           0.62504005,  0.77501005,  0.94487504,  1.14765351,  1.41352783,
#           1.84569542]),
#   array([24.4, 27.6, 27.8, 27.9, 28.5, 30.1, 30.1, 30.3, 31.7, 32.2, 32.8,
#          33.3, 33.5, 34.1, 34.6, 35.8, 35.9, 36.8, 37.1, 39.2, 39.7])),
#  (4.264767709363478, 32.542857142857144, 0.9932431266908159))

# %% [markdown]
# # Aufgabe 5

# %% [markdown]
# ## Aufgabe 5.1

# %%
x = st.norm.rvs(size=10)
st.probplot(x,plot=plt)
# Out:
# ((array([-1.49876728, -0.98494667, -0.64703803, -0.37109819, -0.12121409,
#           0.12121409,  0.37109819,  0.64703803,  0.98494667,  1.49876728]),
#   array([-1.42143208, -1.40734385, -0.91794094, -0.56945133, -0.43877018,
#          -0.41707791, -0.35545835,  0.1343519 ,  1.60618959,  1.7539242 ])),
#  (1.1208226403647166, -0.20330089475002072, 0.9334342816338833))

# %% [markdown]
# ## Aufgabe 5.4

# %%
print(np.exp^(-1.5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-55a4e768f346> in <module>()
# ----> 1 print(np.exp^(-1.5))
#
# TypeError: unsupported operand type(s) for ^: 'numpy.ufunc' and 'float'
